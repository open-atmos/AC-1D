# %%
import xarray as xr

# %%
# strings are immutable and indexing is non-inclusive

str_arr = 'hello world'
str_arr[0:5]      # works as expected
# Out:
# 'hello'

# %%
str_arr[0] = 'H'  # gives an error (Python requires you to define a new string)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-723d71a4d026> in <module>
# ----> 1 str_arr[0] = 'H'  # gives an error (Python requires you to define a new string)
#
# TypeError: 'str' object does not support item assignment

# %%
# equalities are generally pointers unless .copy() is specified

mod_arr = xr.DataArray(np.arange(5))
mod_arr
# Out:
# <xarray.DataArray (dim_0: 5)>
# array([0, 1, 2, 3, 4])
# Dimensions without coordinates: dim_0

# %%
mod_too = mod_arr
mod_arr[0] = 4
mod_too   # surprising!
# Out:
# <xarray.DataArray (dim_0: 5)>
# array([4, 1, 2, 3, 4])
# Dimensions without coordinates: dim_0

# %%
mod_arr = xr.DataArray(np.arange(5))
mod_too = mod_arr.copy()
mod_arr[0] = 4
mod_too   # we needed to make that copy to maintain independent variable
# Out:
# <xarray.DataArray (dim_0: 5)>
# array([0, 1, 2, 3, 4])
# Dimensions without coordinates: dim_0
